# %%
import pyarrow.fs as fs
import pandas as pd

hdfs = fs.HadoopFileSystem("localhost", 9000)

df = pd.read_parquet(
    "/user/pratik/project/orders/orders_gold/5min_window",
    filesystem=hdfs
)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_32691/1877755768.py in <module>
#       2 import pandas as pd
#       3
# ----> 4 hdfs = fs.HadoopFileSystem("localhost", 9000)
#       5
#       6 df = pd.read_parquet(
#
# ~/.local/lib/python3.10/site-packages/pyarrow/_hdfs.pyx in pyarrow._hdfs.HadoopFileSystem.__init__()
#
# ~/.local/lib/python3.10/site-packages/pyarrow/error.pxi in pyarrow.lib.pyarrow_internal_check_status()
#
# ~/.local/lib/python3.10/site-packages/pyarrow/error.pxi in pyarrow.lib.check_status()
#
# OSError: Unable to load libhdfs: ./libhdfs.so: cannot open shared object file: No such file or directory
